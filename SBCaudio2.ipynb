# %%
import view_pmt_trace_3 as vt
#vt.plottrace(pmt)

vlr=vt.loadrecon(0,0)
vlr1=vt.loadrecon1(0,0)
vlr2=vt.loadrecon2(0,0)
vlr3=vt.loadrecon3(0,0)
vlr4=vt.loadrecon4(0,0)
vlr5=vt.loadrecon5(0,0)
vlr6=vt.loadrecon6(0,0)
vlr7=vt.loadrecon7(0,0)
vlr8=vt.loadrecon8(0,0)

print vlr.keys()
print vlr1.keys()
print vlr2.keys()
print vlr3.keys()
print vlr4.keys()
print vlr5.keys()
print vlr6.keys()
print vlr7.keys()
print vlr8.keys()

'''
x=bob['PMT_area']
y=bob['PMT_pulse_height']
print x.shape
print y.shape
'''
# Out:
# /opt/local/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# ['runid', 'ev', 'bubble_t0', 'piezoE', 'peak_t0']
# ['runid', 'ev', 'dytran_fitparams']
# ['runid', 'ev', 'Event_trigger_PLC', 'Event_mstick', 'Event_trigger_main', 'Event_trigger_slowDAQ', 'Event_run_type', 'Event_timestamp', 'Event_livetime', 'Event_Pset', 'Event_trigger_cameras']
# ['runid', 'ev', 'PumpActiveCycle', 'PressureEdge', 'PressureBins', 'PumpActiveTime', 'TempData', 'EventPressure', 'tEvent', 'tGood']
# ['runid', 'ev', 'ibubimage', 'nbubimage', 'cam', 'frame', 'ipix', 'jpix']
# ['runid', 'ev', 'PMT_trigt0_sec', 'PMTfda_nfastDAQhits', 'PMT_trigt0_frac', 'PMTfda_nPMThits', 'PMTfda_ncoinchits']
# ['runid', 'ev', 'pmt_nclusters', 'pmt_npeaks', 'nPMThit', 'iPMThit', 'pmt_nphe']
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x=vlr['bubble_t0']
y=vlr['piezoE']
z=vlr['peak_t0']

print x.shape
print y.shape
print z.shape

plt.figure()
plt.plot(x,z)

plt.figure()
plt.plot(x,y[:,1])
plt.plot(z,y[:,1])

plt.figure()
plt.plot(x,y[:,2])
plt.plot(z,y[:,2])

print y[:,2].shape

plt.show()
# Out:
# (2388,)
# (2388, 3, 3)
# (2388,)
# (2388, 3)

# %%
a=vlr1['dytran_fitparams']
print a.shape

# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(a)
plt.show()
# Out:
# (2388, 4)
# ...

# %%
A=vlr2['Event_trigger_PLC']
B=vlr2['Event_timestamp']
print A.shape
print B.shape

# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(B,A)
plt.show()
# Out:
# (2388,)
# (2388,)

# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(np.arange(x.shape[0]),x[:,1])
plt.ylim(-0.0005,0.0005)
plt.show()

# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

x=vlr['ipix']
y=vlr['jpix']

plt.scatter(x,y)

plt.show()
